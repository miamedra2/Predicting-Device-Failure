# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import scikitplot as skplt
import scipy
# %matplotlib inline
from scipy.stats import linregress
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, roc_auc_score
from statistics import mean
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import scipy.fftpack
from scipy.signal import find_peaks
import datetime as dt
import warnings
warnings.filterwarnings('ignore')

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
ls
# Out:
# 1533148882_failures.csv  HackDay4.ipynb           Untitled.ipynb

# %%
df = pd.read_csv("1533148882_failures.csv")

# %%
df.head()
# Out:
#          date    device  failure  attribute1  attribute2  attribute3  \
# 0  2015-01-01  S1F01085        0   215630672          56           0
# 1  2015-01-01  S1F0166B        0    61370680           0           3
# 2  2015-01-01  S1F01E6Y        0   173295968           0           0
# 3  2015-01-01  S1F01JE0        0    79694024           0           0
# 4  2015-01-01  S1F01R2B        0   135970480           0           0
#
#    attribute4  attribute5  attribute6  attribute7  attribute8  attribute9
# 0          52           6      407438           0           0           7
# 1           0           6      403174           0           0           0
# 2           0          12      237394           0           0           0
# 3           0           6      410186           0           0           0
# 4           0          15      313173           0           0           3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124494 entries, 0 to 124493
# Data columns (total 12 columns):
# date          124494 non-null object
# device        124494 non-null object
# failure       124494 non-null int64
# attribute1    124494 non-null int64
# attribute2    124494 non-null int64
# attribute3    124494 non-null int64
# attribute4    124494 non-null int64
# attribute5    124494 non-null int64
# attribute6    124494 non-null int64
# attribute7    124494 non-null int64
# attribute8    124494 non-null int64
# attribute9    124494 non-null int64
# dtypes: int64(10), object(2)
# memory usage: 11.4+ MB

# %%
abs(df.corr()['failure']).sort_values(ascending = False)
# Out:
# failure       1.000000
# attribute8    0.119055
# attribute7    0.119055
# attribute4    0.067398
# attribute2    0.052902
# attribute5    0.002270
# attribute1    0.001984
# attribute9    0.001622
# attribute3    0.000948
# attribute6    0.000550
# Name: failure, dtype: float64

# %%
df.describe()
# Out:
#              failure    attribute1     attribute2     attribute3  \
# count  124494.000000  1.244940e+05  124494.000000  124494.000000
# mean        0.000851  1.223868e+08     159.484762       9.940455
# std         0.029167  7.045960e+07    2179.657730     185.747321
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%         0.000000  6.127675e+07       0.000000       0.000000
# 50%         0.000000  1.227957e+08       0.000000       0.000000
# 75%         0.000000  1.833084e+08       0.000000       0.000000
# max         1.000000  2.441405e+08   64968.000000   24929.000000
#
#           attribute4     attribute5     attribute6     attribute7  \
# count  124494.000000  124494.000000  124494.000000  124494.000000
# mean        1.741120      14.222693  260172.858025       0.292528
# std        22.908507      15.943021   99151.009852       7.436924
# min         0.000000       1.000000       8.000000       0.000000
# 25%         0.000000       8.000000  221452.000000       0.000000
# 50%         0.000000      10.000000  249799.500000       0.000000
# 75%         0.000000      12.000000  310266.000000       0.000000
# max      1666.000000      98.000000  689161.000000     832.000000
#
#           attribute8     attribute9
# count  124494.000000  124494.000000
# mean        0.292528      12.451524
# std         7.436924     191.425623
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# 75%         0.000000       0.000000
# max       832.000000   18701.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124494 entries, 0 to 124493
# Data columns (total 12 columns):
# date          124494 non-null object
# device        124494 non-null object
# failure       124494 non-null int64
# attribute1    124494 non-null int64
# attribute2    124494 non-null int64
# attribute3    124494 non-null int64
# attribute4    124494 non-null int64
# attribute5    124494 non-null int64
# attribute6    124494 non-null int64
# attribute7    124494 non-null int64
# attribute8    124494 non-null int64
# attribute9    124494 non-null int64
# dtypes: int64(10), object(2)
# memory usage: 11.4+ MB

# %%
df[df['failure'] == 1].shape
# Out:
# (106, 12)

# %%
def cutofflesser(df_in, elem, cutoff):
    
    df_out = df_in[df_in[elem]>cutoff]
    NewTrainingdatasize = df_out.shape[0]
    
    return df_out, NewTrainingdatasize

# %%
def cutoffgreater(df_in, elem, cutoff):
    
    df_out = df_in[df_in[elem]<cutoff]
    NewTrainingdatasize = df_out.shape[0]
    
    return df_out, NewTrainingdatasize

# %%
def plotattributes(dfin):
    
    dfin = dfin.select_dtypes(exclude=['object'])
    
    for elem in dfin:
        plt.hist(dfin[elem], bins=200)
        plt.yscale('log')

        plt.ylabel('counts', fontsize=13)
        plt.xlabel(str(elem), fontsize=13)
        plt.show()

# %%
def GenerateClassPlot(dfin, elem_x, elem_y, model = RandomForestClassifier()):
    
    #model = RandomForestClassifier()
    model.fit(dfin[elem_x].to_frame(), dfin[elem_y])
    x_pred = pd.DataFrame(np.linspace(0, dfin[elem_x].max(), dfin[elem_y].shape[0]))
    y_pred = pd.DataFrame(model.predict(x_pred))
    y_true = dfin[elem_y].to_frame()
    
    
    accuracy = accuracy_score(y_true, y_pred)
    
    #print(x_pred.shape, y_pred.shape, y_true.shape, df[elem_x].to_frame().shape)
    
    fig1 = plt.figure(figsize = (20,5))
    fig1.suptitle(str(elem_x), fontsize=16)
    a = fig1.add_subplot(131)
    a.plot(x_pred, y_pred, 'r')
    a.scatter(dfin[elem_x].to_frame(), y_true)
    a.set_ylabel('Probability of Failure', fontsize=13)
    a.set_xlabel(str(elem_x), fontsize=13)

    b = fig1.add_subplot(132)
    df_1 = dfin[dfin['failure'] == 1]
    df_0 = dfin[dfin['failure'] == 0]
    
    b.hist(df_1[elem_x], bins=50, color = 'orange', zorder = 10)
    b.hist(df_0[elem_x], bins=100, color = 'darkblue',  zorder = 0)
    b.set_yscale('log')
    b.set_ylabel('counts', fontsize=13)
    b.set_xlabel(str(elem_x), fontsize=13)
    
    c = fig1.add_subplot(133)
    fpr, tpr, _ = roc_curve(y_true,  y_pred)
    auc = roc_auc_score(y_true, y_pred)
    c.plot(fpr,tpr,label=str(elem_x)+"\nAUC: "+str(auc)[:6] + "\nAccuracy: "+str(accuracy)[:6])
    c.set_ylabel('True Positive Rate', fontsize=13)
    c.set_xlabel('False Positive Rate', fontsize=13)
    c.legend(loc=4)

# %%
def plotfailureattrvstime(dfin, elem_x):
    
    fig1 = plt.figure(figsize = (20,5))
    a = fig1.add_subplot(121)
    b = fig1.add_subplot(122)
    if(elem_x != 'date' and elem_x != 'device'):
        dfin_x = dfin[dfin['failure'] == 1]
        dfin_y = dfin_x.drop(['date'], axis=1)
        dfin_x2 = dfin[dfin['failure'] == 0]
        dfin_y2 = dfin_x2.drop(['date'], axis=1)
        
        a.scatter(dfin_x2['date'], dfin_y2[elem_x], color = 'darkblue', zorder=0)
        a.scatter(dfin_x['date'], dfin_y[elem_x], color = 'orange', zorder=10)
        a.set_ylabel(str(elem_x), fontsize=13)
        a.set_xlabel('Date', fontsize=13)
        a.set_yscale('log')
        a.title.set_text('Time Domain of '+str(elem_x))

        yf = scipy.fftpack.fft(dfin_y[elem])
        N = len(yf)
        T = 1/1000.0
        xf = np.linspace(0.0, 1.0/(2.0*T), N/2)
        
        yf2 = scipy.fftpack.fft(dfin_y2[elem])
        N2 = len(yf)
        T2 = 1/1000.0
        xf2 = np.linspace(0.0, 1.0/(2.0*T), N/2)
        
        b.plot(xf2, 2.0/N * np.abs(yf2[:N//2]), zorder = 0) 
        b.plot(xf, 2.0/N * np.abs(yf[:N//2]), zorder = 0)  
        b.minorticks_on()
        b.set_yscale('log')
        b.set_ylabel('Amplitude')
        b.set_xlabel('Frequency (1/index)')
        b.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
        b.title.set_text('FFT of '+str(elem_x))

# %%
df1 = df.select_dtypes(exclude=['object'])
df2 = df.select_dtypes(include=['object'])

# %%
for elem in df1:
    GenerateClassPlot(df1, elem, 'failure', GradientBoostingClassifier())

# %%
for elem in df:
    if(elem != 'date' and elem != 'device' and elem != 'failure'):
        plotfailureattrvstime(df, elem)

# %%
abs(df.corr()['failure'].sort_values(ascending = False))
# Out:
# failure       1.000000
# attribute8    0.119055
# attribute7    0.119055
# attribute4    0.067398
# attribute2    0.052902
# attribute5    0.002270
# attribute1    0.001984
# attribute9    0.001622
# attribute6    0.000550
# attribute3    0.000948
# Name: failure, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124494 entries, 0 to 124493
# Data columns (total 12 columns):
# date          124494 non-null object
# device        124494 non-null object
# failure       124494 non-null int64
# attribute1    124494 non-null int64
# attribute2    124494 non-null int64
# attribute3    124494 non-null int64
# attribute4    124494 non-null int64
# attribute5    124494 non-null int64
# attribute6    124494 non-null int64
# attribute7    124494 non-null int64
# attribute8    124494 non-null int64
# attribute9    124494 non-null int64
# dtypes: int64(10), object(2)
# memory usage: 11.4+ MB

# %%
df.head()
# Out:
#          date    device  failure  attribute1  attribute2  attribute3  \
# 0  2015-01-01  S1F01085        0   215630672          56           0
# 1  2015-01-01  S1F0166B        0    61370680           0           3
# 2  2015-01-01  S1F01E6Y        0   173295968           0           0
# 3  2015-01-01  S1F01JE0        0    79694024           0           0
# 4  2015-01-01  S1F01R2B        0   135970480           0           0
#
#    attribute4  attribute5  attribute6  attribute7  attribute8  attribute9
# 0          52           6      407438           0           0           7
# 1           0           6      403174           0           0           0
# 2           0          12      237394           0           0           0
# 3           0           6      410186           0           0           0
# 4           0          15      313173           0           0           3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124494 entries, 0 to 124493
# Data columns (total 12 columns):
# date          124494 non-null object
# device        124494 non-null object
# failure       124494 non-null int64
# attribute1    124494 non-null int64
# attribute2    124494 non-null int64
# attribute3    124494 non-null int64
# attribute4    124494 non-null int64
# attribute5    124494 non-null int64
# attribute6    124494 non-null int64
# attribute7    124494 non-null int64
# attribute8    124494 non-null int64
# attribute9    124494 non-null int64
# dtypes: int64(10), object(2)
# memory usage: 11.4+ MB

# %%
df.head()
# Out:
#          date    device  failure  attribute1  attribute2  attribute3  \
# 0  2015-01-01  S1F01085        0   215630672          56           0
# 1  2015-01-01  S1F0166B        0    61370680           0           3
# 2  2015-01-01  S1F01E6Y        0   173295968           0           0
# 3  2015-01-01  S1F01JE0        0    79694024           0           0
# 4  2015-01-01  S1F01R2B        0   135970480           0           0
#
#    attribute4  attribute5  attribute6  attribute7  attribute8  attribute9
# 0          52           6      407438           0           0           7
# 1           0           6      403174           0           0           0
# 2           0          12      237394           0           0           0
# 3           0           6      410186           0           0           0
# 4           0          15      313173           0           0           3

# %%
#df['date'] = pd.to_datetime(df['date']).map(dt.datetime.toordinal)

# %%
#df['date'] = df['date'] - df['date'].min()

# %%
df.head()
# Out:
#          date    device  failure  attribute1  attribute2  attribute3  \
# 0  2015-01-01  S1F01085        0   215630672          56           0
# 1  2015-01-01  S1F0166B        0    61370680           0           3
# 2  2015-01-01  S1F01E6Y        0   173295968           0           0
# 3  2015-01-01  S1F01JE0        0    79694024           0           0
# 4  2015-01-01  S1F01R2B        0   135970480           0           0
#
#    attribute4  attribute5  attribute6  attribute7  attribute8  attribute9
# 0          52           6      407438           0           0           7
# 1           0           6      403174           0           0           0
# 2           0          12      237394           0           0           0
# 3           0           6      410186           0           0           0
# 4           0          15      313173           0           0           3

# %%
df['date'] = pd.to_datetime(df['date'])
df['date'] = df['date'].apply(lambda x: x.toordinal())

# %%
df = df.groupby('device').last()
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#      device    date  failure  attribute1  attribute2  attribute3  attribute4  \
# 0  S1F01085  735604        0   128832128          56           0          52
# 1  S1F013BB  735729        0   115676688           0           0           0
# 2  S1F0166B  735604        0     7441792           0           3           0
# 3  S1F01E6Y  735646        0   147350000           0           0           0
# 4  S1F01JE0  735604        0   185424928           0           0           0
#
#    attribute5  attribute6  attribute7  attribute8  attribute9
# 0           6      409404           0           0           7
# 1           5      689161           0           0           0
# 2           6      404786           0           0           0
# 3          12      259491           0           0           0
# 4           6      412151           0           0           0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 12 columns):
# device        1168 non-null object
# date          1168 non-null int64
# failure       1168 non-null int64
# attribute1    1168 non-null int64
# attribute2    1168 non-null int64
# attribute3    1168 non-null int64
# attribute4    1168 non-null int64
# attribute5    1168 non-null int64
# attribute6    1168 non-null int64
# attribute7    1168 non-null int64
# attribute8    1168 non-null int64
# attribute9    1168 non-null int64
# dtypes: int64(11), object(1)
# memory usage: 109.6+ KB

# %%
df1 = df.select_dtypes(exclude=['object'])
df2 = df.select_dtypes(include=['object'])

# %%
for elem in df1:
    GenerateClassPlot(df1, elem, 'failure', GradientBoostingClassifier())

# %% [markdown]
# ### Attribute3

# %%
cutoff_vals = np.linspace(1, 100, 100)
[{len(df[df['failure']==1][df['attribute3']<elem])/len(df[df['failure']==0][df['attribute3']<elem]), elem} for elem in cutoff_vals]
# Out:
# [{0.09276248725790011, 1.0},
#  {0.09542743538767395, 2.0},
#  {0.09683794466403162, 3.0},
#  {0.09645669291338582, 4.0},
#  {0.0962671905697446, 5.0},
#  {0.09598432908912831, 6.0},
#  {0.09598432908912831, 7.0},
#  {0.0958904109589041, 8.0},
#  {0.0966796875, 9.0},
#  {0.09639727361246349, 10.0},
#  {0.0963035019455253, 11.0},
#  {0.09602327837051407, 12.0},
#  {0.09583736689254599, 13.0},
#  {0.09583736689254599, 14.0},
#  {0.09565217391304348, 15.0},
#  {0.09555984555984556, 16.0},
#  {0.09546769527483125, 17.0},
#  {0.09546769527483125, 18.0},
#  {0.0953757225433526, 19.0},
#  {0.0953757225433526, 20.0},
#  {0.0953757225433526, 21.0},
#  {0.09510086455331412, 22.0},
#  {0.09510086455331412, 23.0},
#  {0.09510086455331412, 24.0},
#  {0.09510086455331412, 25.0},
#  {0.09500959692898273, 26.0},
#  {0.09500959692898273, 27.0},
#  {0.09500959692898273, 28.0},
#  {0.09500959692898273, 29.0},
#  {0.09500959692898273, 30.0},
#  {0.09500959692898273, 31.0},
#  {0.09500959692898273, 32.0},
#  {0.09500959692898273, 33.0},
#  {0.09500959692898273, 34.0},
#  {0.09482758620689655, 35.0},
#  {0.09473684210526316, 36.0},
#  {0.09464627151051626, 37.0},
#  {0.09464627151051626, 38.0},
#  {0.09464627151051626, 39.0},
#  {0.09464627151051626, 40.0},
#  {0.09464627151051626, 41.0},
#  {0.09464627151051626, 42.0},
#  {0.09464627151051626, 43.0},
#  {0.09464627151051626, 44.0},
#  {0.09464627151051626, 45.0},
#  {0.09464627151051626, 46.0},
#  {0.09464627151051626, 47.0},
#  {0.09464627151051626, 48.0},
#  {0.09464627151051626, 49.0},
#  {0.09464627151051626, 50.0},
#  {0.09464627151051626, 51.0},
#  {0.09464627151051626, 52.0},
#  {0.09464627151051626, 53.0},
#  {0.09455587392550144, 54.0},
#  {0.09455587392550144, 55.0},
#  {0.09455587392550144, 56.0},
#  {0.09446564885496184, 57.0},
#  {0.09446564885496184, 58.0},
#  {0.09446564885496184, 59.0},
#  {0.09446564885496184, 60.0},
#  {0.09446564885496184, 61.0},
#  {0.09437559580552908, 62.0},
#  {0.09428571428571429, 63.0},
#  {0.09428571428571429, 64.0},
#  {0.09428571428571429, 65.0},
#  {0.09428571428571429, 66.0},
#  {0.09428571428571429, 67.0},
#  {0.09428571428571429, 68.0},
#  {0.09428571428571429, 69.0},
#  {0.09428571428571429, 70.0},
#  {0.09523809523809523, 71.0},
#  {0.09523809523809523, 72.0},
#  {0.09514747859181731, 73.0},
#  {0.09514747859181731, 74.0},
#  {0.09514747859181731, 75.0},
#  {0.09514747859181731, 76.0},
#  {0.09514747859181731, 77.0},
#  {0.09514747859181731, 78.0},
#  {0.09514747859181731, 79.0},
#  {0.09514747859181731, 80.0},
#  {0.09514747859181731, 81.0},
#  {0.09514747859181731, 82.0},
#  {0.09514747859181731, 83.0},
#  {0.09514747859181731, 84.0},
#  {0.09514747859181731, 85.0},
#  {0.09514747859181731, 86.0},
#  {0.09514747859181731, 87.0},
#  {0.09514747859181731, 88.0},
#  {0.09514747859181731, 89.0},
#  {0.09514747859181731, 90.0},
#  {0.09514747859181731, 91.0},
#  {0.09514747859181731, 92.0},
#  {0.09514747859181731, 93.0},
#  {0.09514747859181731, 94.0},
#  {0.09514747859181731, 95.0},
#  {0.09514747859181731, 96.0},
#  {0.09514747859181731, 97.0},
#  {0.09514747859181731, 98.0},
#  {0.09514747859181731, 99.0},
#  {0.09514747859181731, 100.0}]

# %%
dfmod, trainsize = cutoffgreater(df, 'attribute3', 17)

# %%
dfmod[dfmod['failure'] == 1].shape
# Out:
# (99, 12)

# %%
dfmod[dfmod['failure'] == 0].shape
# Out:
# (1037, 12)

# %%
GenerateClassPlot(dfmod, 'attribute3', 'failure', GradientBoostingClassifier())

# %% [markdown]
# ###  Attribute 9

# %%
cutoff_vals = np.linspace(1, 100, 100)
[{len(df[df['failure']==1][df['attribute9']<elem])/len(df[df['failure']==0][df['attribute9']<elem]), elem} for elem in cutoff_vals]
# Out:
# [{0.09137055837563451, 1.0},
#  {0.08853575482406356, 2.0},
#  {0.0916030534351145, 3.0},
#  {0.09341825902335456, 4.0},
#  {0.09109730848861283, 5.0},
#  {0.09304703476482618, 6.0},
#  {0.09219858156028368, 7.0},
#  {0.09356136820925554, 8.0},
#  {0.09272183449651047, 9.0},
#  {0.09343936381709742, 10.0},
#  {0.09405940594059406, 11.0},
#  {0.09495548961424333, 12.0},
#  {0.0947680157946693, 13.0},
#  {0.09448818897637795, 14.0},
#  {0.09430255402750491, 15.0},
#  {0.09421000981354269, 16.0},
#  {0.09421000981354269, 17.0},
#  {0.09421000981354269, 18.0},
#  {0.0940254652301665, 19.0},
#  {0.09500489715964741, 20.0},
#  {0.0949119373776908, 21.0},
#  {0.0947265625, 22.0},
#  {0.0947265625, 23.0},
#  {0.09463414634146342, 24.0},
#  {0.09444985394352483, 25.0},
#  {0.0943579766536965, 26.0},
#  {0.09426627793974733, 27.0},
#  {0.09426627793974733, 28.0},
#  {0.09426627793974733, 29.0},
#  {0.09426627793974733, 30.0},
#  {0.0941747572815534, 31.0},
#  {0.0941747572815534, 32.0},
#  {0.0941747572815534, 33.0},
#  {0.0939922480620155, 34.0},
#  {0.09381044487427466, 35.0},
#  {0.09381044487427466, 36.0},
#  {0.09381044487427466, 37.0},
#  {0.09381044487427466, 38.0},
#  {0.09371980676328502, 39.0},
#  {0.09371980676328502, 40.0},
#  {0.09371980676328502, 41.0},
#  {0.09468599033816426, 42.0},
#  {0.0945945945945946, 43.0},
#  {0.0945945945945946, 44.0},
#  {0.0945945945945946, 45.0},
#  {0.0945945945945946, 46.0},
#  {0.0945945945945946, 47.0},
#  {0.0945945945945946, 48.0},
#  {0.0945945945945946, 49.0},
#  {0.0945945945945946, 50.0},
#  {0.0945945945945946, 51.0},
#  {0.09450337512054002, 52.0},
#  {0.09546769527483125, 53.0},
#  {0.09546769527483125, 54.0},
#  {0.09546769527483125, 55.0},
#  {0.09546769527483125, 56.0},
#  {0.09546769527483125, 57.0},
#  {0.0953757225433526, 58.0},
#  {0.0953757225433526, 59.0},
#  {0.0953757225433526, 60.0},
#  {0.0953757225433526, 61.0},
#  {0.0953757225433526, 62.0},
#  {0.0953757225433526, 63.0},
#  {0.0953757225433526, 64.0},
#  {0.0953757225433526, 65.0},
#  {0.09528392685274302, 66.0},
#  {0.09528392685274302, 67.0},
#  {0.09528392685274302, 68.0},
#  {0.09528392685274302, 69.0},
#  {0.09528392685274302, 70.0},
#  {0.09519230769230769, 71.0},
#  {0.09519230769230769, 72.0},
#  {0.09519230769230769, 73.0},
#  {0.09519230769230769, 74.0},
#  {0.09519230769230769, 75.0},
#  {0.09519230769230769, 76.0},
#  {0.09519230769230769, 77.0},
#  {0.09519230769230769, 78.0},
#  {0.09519230769230769, 79.0},
#  {0.09519230769230769, 80.0},
#  {0.09519230769230769, 81.0},
#  {0.09519230769230769, 82.0},
#  {0.09519230769230769, 83.0},
#  {0.09519230769230769, 84.0},
#  {0.09519230769230769, 85.0},
#  {0.09519230769230769, 86.0},
#  {0.09519230769230769, 87.0},
#  {0.09519230769230769, 88.0},
#  {0.09519230769230769, 89.0},
#  {0.09519230769230769, 90.0},
#  {0.09519230769230769, 91.0},
#  {0.09519230769230769, 92.0},
#  {0.09519230769230769, 93.0},
#  {0.09519230769230769, 94.0},
#  {0.09519230769230769, 95.0},
#  {0.09519230769230769, 96.0},
#  {0.09519230769230769, 97.0},
#  {0.09519230769230769, 98.0},
#  {0.09510086455331412, 99.0},
#  {0.09510086455331412, 100.0}]

# %%
dfmod, trainsize = cutoffgreater(dfmod, 'attribute9', 43)

# %%
dfmod[dfmod['failure'] == 1].shape
# Out:
# (97, 12)

# %%
dfmod[dfmod['failure'] == 0].shape
# Out:
# (1019, 12)

# %%
GenerateClassPlot(dfmod, 'attribute9', 'failure', GradientBoostingClassifier())

# %% [markdown]
# ### Attribute 5

# %%
dfmod['attribute5'] = dfmod['attribute5'].apply(lambda x: np.log(x+1))

# %%
GenerateClassPlot(dfmod, 'attribute5', 'failure', GradientBoostingClassifier())

# %%
dfmod2, trainsize = cutofflesser(dfmod, 'attribute5', 1.5)

# %%
dfmod2['attribute5'] = dfmod2['attribute5'].apply(lambda x:np.log(x))

# %%
GenerateClassPlot(dfmod2, 'attribute5', 'failure', GradientBoostingClassifier())

# %%
df.drop('device',axis=1, inplace = True)

# %% [markdown]
# ### Random Undersampling

# %%
count_class_0, count_class_1 = df.failure.value_counts()

# %%
df_class_0 = df[df['failure'] == 0]
df_class_1 = df[df['failure'] == 1]

# %%
df_class_0_under = df_class_0.sample(count_class_1)
df_under = pd.concat([df_class_0_under, df_class_1], axis=0)

# %%
df_under.failure.value_counts().plot(kind='bar', title='Count (failure)');

# %% [markdown]
# ### Random Oversampling

# %%
df_class_1_over = df_class_1.sample(count_class_0, replace=True)
df_over = pd.concat([df_class_0, df_class_1_over], axis=0)

# %%
df_over.failure.value_counts().plot(kind='bar', title='Count (failure)');

# %%
abs(df_under.corr()['failure']).sort_values(ascending = False)
# Out:
# failure       1.000000
# attribute8    0.182790
# attribute7    0.182790
# attribute4    0.123332
# attribute2    0.117666
# attribute5    0.115243
# attribute3    0.073003
# attribute9    0.063012
# attribute6    0.050190
# attribute1    0.008357
# date          0.006421
# Name: failure, dtype: float64

# %%
abs(df_over.corr()['failure']).sort_values(ascending = False)
# Out:
# failure       1.000000
# attribute2    0.186015
# attribute8    0.177115
# attribute7    0.177115
# attribute4    0.164671
# attribute5    0.132467
# attribute6    0.078267
# attribute1    0.045125
# attribute3    0.027065
# date          0.025888
# attribute9    0.021620
# Name: failure, dtype: float64

# %%
for elem in df_under:
    GenerateClassPlot(df_under, elem, 'failure', GradientBoostingClassifier())

# %%
#df_under.drop(['attribute6', 'attribute4', 'attribute3', 'attribute2'], axis=1, inplace=True)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
def GenAUCCurve(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    fpr, tpr, _ = roc_curve(y_true,  y_pred)
    auc = roc_auc_score(y_true, y_pred)
    plt.plot(fpr,tpr)
    plt.legend(["\nAUC: "+str(auc)[:6] + "\nAccuracy: "+str(accuracy)[:6]], loc='best')
    plt.ylabel('True Positive Rate', fontsize=13)
    plt.xlabel('False Positive Rate', fontsize=13)
    plt.show()

# %%
def OptimalRegression(XData, y):
    
    g = GaussianNB()
    b = BernoulliNB()
    k = KNeighborsClassifier()
    log = LogisticRegression()
    gbc = GradientBoostingClassifier()
    d = DecisionTreeClassifier()
    r = RandomForestClassifier()
    
    algorithms = [g,b,k,log,d,r,gbc]
    names = ['GaussianNB', 'BernoulliNB', 'K Nearest', 'Logistic','Single Tree','Random Forest', 'GradientBoost']

    x_train, x_test, y_train, y_test = train_test_split(XData, y, train_size=0.8, random_state=0)
    
    # fit the data
    # print metrics
    accuracy = []
    precision = []
    recall = []
    f1 = []
    
    largest_f1 = 0
    bestmodel = 0
        
    for algo in algorithms:
        algo.fit(x_train,y_train)
        y_pred = algo.predict(x_test)
        
        accuracy.append(accuracy_score(y_test, y_pred))
        precision.append(precision_score(y_test, y_pred))
        recall.append(recall_score(y_test, y_pred))
        f1_val = f1_score(y_test, y_pred)
        f1.append(f1_val)
        if(f1_val < .95) and (f1_val > largest_f1):
            largest_f1 = f1_val
            bestmodel = algo
        
    metrics = pd.DataFrame(columns = ['Accuracy', 'Precision', 'Recall', 'F1'], index = names)
    metrics['Accuracy'] = accuracy
    metrics['Precision'] = precision
    metrics['Recall'] = recall
    metrics['F1'] = f1
     
    stats = metrics.sort_values('F1', ascending = False)
    
    bestmodel.fit(x_train,y_train)
    y_pred = algo.predict(x_test)
    
    GenAUCCurve(y_test, y_pred)
    print(largest_f1)
    
    return bestmodel, stats

# %%
model_under, stats = OptimalRegression(df_under.drop('failure', axis=1), df_under['failure'])
stats
# Out:
# 0.909090909090909
#                Accuracy  Precision    Recall        F1
# GradientBoost  0.902439   0.952381  0.869565  0.909091
# Random Forest  0.853659   0.869565  0.869565  0.869565
# Single Tree    0.829268   0.863636  0.826087  0.844444
# BernoulliNB    0.707317   0.823529  0.608696  0.700000
# K Nearest      0.609756   0.652174  0.652174  0.652174
# GaussianNB     0.512195   1.000000  0.130435  0.230769
# Logistic       0.439024   0.000000  0.000000  0.000000

# %%
model_over, stats = OptimalRegression(df_over.drop('failure', axis=1), df_over['failure'])
stats
# Out:
# 0.8552915766738661
#                Accuracy  Precision    Recall        F1
# Single Tree    0.978923   0.957547  1.000000  0.978313
# Random Forest  0.978923   0.957547  1.000000  0.978313
# GradientBoost  0.974239   0.961538  0.985222  0.973236
# K Nearest      0.843091   0.761538  0.975369  0.855292
# BernoulliNB    0.737705   0.827338  0.566502  0.672515
# Logistic       0.529274   0.504673  0.532020  0.517986
# GaussianNB     0.597190   0.918919  0.167488  0.283333

# %%
def plot_learn_curves(model1, model2, dataset, y_name):
    
    x = dataset.drop(y_name,axis = 1) 
    y_test = dataset[y_name]
    
    algorithms = [model1, model2]
    names = ['under', 'over']
    
    accuracy = []
    precision = []
    recall = []
    f1 = []
        
    for algo in algorithms:
        y_pred = algo.predict(x)
        
        accuracy.append(accuracy_score(y_test, y_pred))
        precision.append(precision_score(y_test, y_pred))
        recall.append(recall_score(y_test, y_pred))
        f1_val = f1_score(y_test, y_pred)
        f1.append(f1_val)
        
        GenAUCCurve(y_test, y_pred)
    
    metrics = pd.DataFrame(columns = ['Accuracy', 'Precision', 'Recall', 'F1'], index = names)
    metrics['Accuracy'] = accuracy
    metrics['Precision'] = precision
    metrics['Recall'] = recall
    metrics['F1'] = f1
     
    stats = metrics.sort_values('F1', ascending = False)
    
    return stats

# %%
plot_learn_curves(model_under, model_over, df, 'failure')
# Out:
#        Accuracy  Precision    Recall        F1
# under  0.990582   0.959184  0.930693  0.944724
# over   0.809932   0.310345  0.980198  0.471429
